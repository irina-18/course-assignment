# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Irina**
# I would like to become a data scientist.

# %% [markdown]
# *I am interested in data sciente because is an evolving field.*

# %% [markdown]
# ### The next cell is going to make a sum

# %%
1 + 1

# %% [markdown]
# ---
# * 1
# * 2
# * 3
# 1. a
# 2. b
# 3. c
